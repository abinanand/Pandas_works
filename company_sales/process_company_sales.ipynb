# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\ABIN ANAND\\Desktop\\ML_works\\pandas_works\\company_sales\\company_sales_data.csv")

# %%
df.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# month_number    0
# facecream       0
# facewash        0
# toothpaste      0
# bathingsoap     0
# shampoo         0
# moisturizer     0
# total_units     0
# total_profit    0
# dtype: int64

# %%
#Total profit of all month

total_profit_month = df.groupby("month_number")["total_profit"].sum()
plt.bar(total_profit_month.index,total_profit_month.values)
plt.xlabel("MONTH")
plt.ylabel("TOTAL PROFIT")
plt.title("MONTH WISE TOTAL PROFIT")
# Out:
# Text(0.5, 1.0, 'MONTH WISE TOTAL PROFIT')
