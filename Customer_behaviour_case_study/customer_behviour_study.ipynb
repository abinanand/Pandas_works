# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\ABIN ANAND\\Desktop\\ML_works\\pandas_works\\Customer_behaviour_case_study\\E-commerce Customer Behavior - Sheet1.csv")
df.head(3)
# Out:
#    Customer ID  Gender  Age         City Membership Type  Total Spend  \
# 0          101  Female   29     New York            Gold      1120.20
# 1          102    Male   34  Los Angeles          Silver       780.50
# 2          103  Female   43      Chicago          Bronze       510.75
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
df.rename(columns={"Customer ID":"customer_id","Gender":"gender","Age":"age","City":"city","Membership Type":"membership_type","Total Spend":"total_spend","Items Purchased":"items_purchased","Average Rating":"average_rating","Discount Applied":"discount_applied","Days Since Last Purchase":"days_since_last_purchase","Satisfaction Level":"satisfaction_level"},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'membership_type',
#        'total_spend', 'items_purchased', 'average_rating', 'discount_applied',
#        'days_since-last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
df.rename(columns={"days_since-last_purchase":"days_since_last_purchase"},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'membership_type',
#        'total_spend', 'items_purchased', 'average_rating', 'discount_applied',
#        'days_since_last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
df["satisfaction_level"].fillna("unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id                 0
# gender                      0
# age                         0
# city                        0
# membership_type             0
# total_spend                 0
# items_purchased             0
# average_rating              0
# discount_applied            0
# days_since_last_purchase    0
# satisfaction_level          0
# dtype: int64

# %%
"Customer ID":"customer_id","Gender":"gender","Age":"age","City":"city","Membership Type":"membership_type","Total Spend":"total_spend","Items Purchased":"items_purchased","Average Rating":"average_rating","Discount Applied":"discount_applied","Days Since Last Purchase":"days_since-last_purchase","Satisfaction Level":"satisfaction_level"}inplace=True)
