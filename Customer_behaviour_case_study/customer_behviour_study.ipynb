# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\ABIN ANAND\\Desktop\\ML_works\\pandas_works\\Customer_behaviour_case_study\\E-commerce Customer Behavior - Sheet1.csv")
df.head(3)
# Out:
#    Customer ID  Gender  Age         City Membership Type  Total Spend  \
# 0          101  Female   29     New York            Gold      1120.20
# 1          102    Male   34  Los Angeles          Silver       780.50
# 2          103  Female   43      Chicago          Bronze       510.75
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
df.rename(columns={"Customer ID":"customer_id","Gender":"gender","Age":"age","City":"city","Membership Type":"membership_type","Total Spend":"total_spend","Items Purchased":"items_purchased","Average Rating":"average_rating","Discount Applied":"discount_applied","Days Since Last Purchase":"days_since_last_purchase","Satisfaction Level":"satisfaction_level"},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'membership_type',
#        'total_spend', 'items_purchased', 'average_rating', 'discount_applied',
#        'days_since_last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
df.rename(columns={"days_since-last_purchase":"days_since_last_purchase"},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'membership_type',
#        'total_spend', 'items_purchased', 'average_rating', 'discount_applied',
#        'days_since_last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
df["satisfaction_level"].fillna("unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id                 0
# gender                      0
# age                         0
# city                        0
# membership_type             0
# total_spend                 0
# items_purchased             0
# average_rating              0
# discount_applied            0
# days_since_last_purchase    0
# satisfaction_level          0
# dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    175
# Male      175
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

gender_count = df["gender"].value_counts()

# %%
plt.plot(gender_count,marker="o",linestyle="none")
plt.title("Gender wise count")
plt.xlabel("gender")
plt.ylabel("count")
plt.show()

# %%
# Customer average age
df["age"].mean().astype("int")
# Out:
# np.int64(33)

# %%
# unique membership
df["membership_type"].unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
ms_count = df["membership_type"].value_counts()

# %%
plt.plot(ms_count,marker="o",linestyle="dashed")
plt.xlabel("membership type",color="red")
plt.ylabel("customer count",color="red")
plt.title("membership wise count",color="green")
# Out:
# Text(0.5, 1.0, 'membership wise count')

# %%
# membership wise total_spend summary
membership_total_spend = df.groupby("membership_type")["total_spend"].sum()
membership_total_spend
# Out:
# membership_type
# Bronze     54913.1
# Gold      153403.9
# Silver     87566.6
# Name: total_spend, dtype: float64

# %%
plt.bar(membership_total_spend.index,membership_total_spend.values,color="purple")
plt.xlabel("membership type")
plt.ylabel("membership count")
plt.title("membership wise chart",color = "red")
# Out:
# Text(0.5, 1.0, 'membership wise chart')

# %%
# gold members
df[df["membership_type"]=="Gold"]
# Out:
#      customer_id  gender  age           city membership_type  total_spend  \
# 0            101  Female   29       New York            Gold       1120.2
# 3            104    Male   30  San Francisco            Gold       1480.3
# 6            107  Female   31       New York            Gold       1150.6
# 9            110    Male   28  San Francisco            Gold       1520.1
# 12           113  Female   30       New York            Gold       1200.8
# ..           ...     ...  ...            ...             ...          ...
# 335          436  Female   30       New York            Gold       1200.8
# 338          439    Male   30  San Francisco            Gold       1460.5
# 341          442  Female   31       New York            Gold       1140.6
# 344          445    Male   28  San Francisco            Gold       1480.1
# 347          448  Female   30       New York            Gold       1190.8
#
#      items_purchased  average_rating  discount_applied  \
# ...

# %%
# Rating above = 4.5
df[df["average_rating"]>4.5]
# Out:
#      customer_id  gender  age           city membership_type  total_spend  \
# 0            101  Female   29       New York            Gold       1120.2
# 3            104    Male   30  San Francisco            Gold       1480.3
# 9            110    Male   28  San Francisco            Gold       1520.1
# 15           116    Male   29  San Francisco            Gold       1360.2
# 18           119  Female   32       New York            Gold       1170.3
# ..           ...     ...  ...            ...             ...          ...
# 326          427    Male   30  San Francisco            Gold       1450.5
# 332          433    Male   28  San Francisco            Gold       1490.1
# 335          436  Female   30       New York            Gold       1200.8
# 338          439    Male   30  San Francisco            Gold       1460.5
# 344          445    Male   28  San Francisco            Gold       1480.1
#
#      items_purchased  average_rating  discount_applied  \
# ...

# %%
# customers per city [plot]

customer_per_city = df["city"].value_counts()
customer_per_city
# Out:
# city
# New York         59
# Los Angeles      59
# Chicago          58
# San Francisco    58
# Miami            58
# Houston          58
# Name: count, dtype: int64

# %%
plt.bar(customer_per_city.index,customer_per_city.values,color = "green")
# Out:
# <BarContainer object of 6 artists>

# %%
# city wise total spend [plot]
city_wise_total_spend = df.groupby("city")["total_spend"].sum()
city_wise_total_spend
# Out:
# city
# Chicago          28993.2
# Houston          25919.9
# Los Angeles      47524.0
# Miami            40042.6
# New York         68737.1
# San Francisco    84666.8
# Name: total_spend, dtype: float64

# %%
plt.bar(city_wise_total_spend.index,city_wise_total_spend.values,color="red",width=0.5)
plt.xlabel("CITY",color = "green")
plt.ylabel("COUNT",color = "green")
plt.title("MEMBERSHIP WISE COUNT",color = "green")
# Out:
# Text(0.5, 1.0, 'MEMBERSHIP WISE COUNT')

# %%
plt.pie(city_wise_total_spend.values,labels=city_wise_total_spend.index,autopct="%1.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x203b052b0e0>,
# ...
#  [Text(1.0482892953801437, 0.3333009948851073, 'Chicago'),
#   Text(0.6915931686830732, 0.8553939963729618, 'Houston'),
#   Text(-0.10970201354560376, 1.094516088609044, 'Los Angeles'),
#   Text(-0.9428293511093423, 0.5666328746964271, 'Miami'),
#   Text(-0.8991876248554197, -0.633609986748054, 'New York'),
#   Text(0.684663489670123, -0.860950582735577, 'San Francisco')],
#  [Text(0.5717941611164419, 0.18180054266460394, '9.8%'),
#   Text(0.3772326374634944, 0.4665785434761609, '8.8%'),
#   Text(-0.05983746193396568, 0.5970087756049329, '16.1%'),
#   Text(-0.5142705551505503, 0.309072477107142, '13.5%'),
#   Text(-0.49046597719386525, -0.34560544731712034, '23.2%'),
#   Text(0.3734528125473398, -0.4696094087648601, '28.6%')])

# %%
# city wise averae rating

city_wise_avg_rating = df.groupby("city")["average_rating"].mean()
city_wise_avg_rating
# Out:
# city
# Chicago          3.456897
# Houston          3.193103
# Los Angeles      4.172881
# Miami            3.927586
# New York         4.544068
# San Francisco    4.808621
# Name: average_rating, dtype: float64

# %%
plt.bar(city_wise_avg_rating.index,city_wise_avg_rating.values,width=0.5)
plt.xlabel("CITY",color="green")
plt.ylabel("AVERAGE RATING",color ="green")
plt.title("CITY WISE AVERAGE RATING")
# Out:
# Text(0.5, 1.0, 'CITY WISE AVERAGE RATING')

# %%
age_total_spend = df.groupby("age")["total_spend"].mean()
age_total_spend
# Out:
# age
# 26     689.488889
# 27     710.820000
# 28    1492.183333
# 29    1290.218182
# 30    1325.645833
# 31    1144.600000
# 32     805.451515
# 33     820.640000
# 34     791.045833
# 35     800.088000
# 36     500.912000
# 37     432.050000
# 38     444.233333
# 41     484.416667
# 42     518.716667
# 43     507.950000
# Name: total_spend, dtype: float64

# %%
# Scatter chart
plt.scatter(age_total_spend.index,age_total_spend.values,label="SPEND")
plt.legend()

# %%
# Histogram chart
plt.hist(df["age"],bins=10,edgecolor="white")
# Out:
# (array([34., 35., 73., 33., 34., 50., 24.,  9., 24., 34.]),
#  array([26. , 27.7, 29.4, 31.1, 32.8, 34.5, 36.2, 37.9, 39.6, 41.3, 43. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
figure,axes=plt.subplots(2,2)
x=np.array([2,3,4,5,6])
axes[0,0].plot(x,x+2)
axes[0,1].bar(x,x**3)
axes[1,0].plot(x,x**10)
axes[1,1].plot(x,x**5)

# %%
age=[2,23,24,22,25,23,13,70,33,23,23,21,28,26,3,33,22,21,22,24,25,26,23,21]
plt.boxplot(age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x203ae1b1400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x203ae1b1940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x203ae1b1550>],
#  'medians': [<matplotlib.lines.Line2D at 0x203b1bf1fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x203b1bf1e80>],
#  'means': []}
